# %%
import pandas as pd
import numpy as np
import datetime
from numpy import array
import dateutil.parser as parser

# %%
df_retail_2009_2010 = pd.read_csv('Cleaned20092010.csv')
# Out:
# /Users/piumallick/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3051: DtypeWarning: Columns (0,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_retail_2009_2010.head()
# Out:
#    Invoice StockCode                  Description  Quantity InvoiceDate  \
# 0  C503527     10002  INFLATABLE POLITICAL GLOBE        200      4/1/10
# 1  C507219     10002  INFLATABLE POLITICAL GLOBE          1      5/6/10
# 2  C508132     10002  INFLATABLE POLITICAL GLOBE        400     5/13/10
# 3  C508134     10002  INFLATABLE POLITICAL GLOBE        400     5/13/10
# 4  C508140     10002  INFLATABLE POLITICAL GLOBE        200     5/13/10
#
#    InvoiceTime  Price  Customer ID         Country SubTotal
# 0   1:13:00 PM   0.72        16019  United Kingdom   144.00
# 1   7:14:00 PM   0.85        14713  United Kingdom     0.85
# 2  10:54:00 AM   0.72        12931  United Kingdom   288.00
# 3  10:56:00 AM   0.72        12931  United Kingdom   288.00
# 4  10:58:00 AM   0.72        12931  United Kingdom   144.00

# %%
df_retail_2009_2010.shape
# Out:
# (413084, 10)

# %%
df_retail_2010_2011 = pd.read_csv('Cleaned20102011.csv')

# %%
df_retail_2010_2011.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 1  536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 2  536365     71053                  WHITE METAL LANTERN         6
# 3  536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4  536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#   InvoiceDate InvoiceTime  Price  Customer ID         Country SubTotal
# 0     12/1/10  8:26:00 AM   7.65        17850  United Kingdom    15.30
# 1     12/1/10  8:26:00 AM   2.55        17850  United Kingdom    15.30
# 2     12/1/10  8:26:00 AM   3.39        17850  United Kingdom    20.34
# 3     12/1/10  8:26:00 AM   3.39        17850  United Kingdom    20.34
# 4     12/1/10  8:26:00 AM   3.39        17850  United Kingdom    20.34

# %%
df_retail_2010_2011.shape
# Out:
# (300766, 10)

# %%
df_retail = df_retail_2009_2010.append(df_retail_2010_2011, ignore_index=True)

# %%
df_retail.head()
# Out:
#    Invoice StockCode                  Description  Quantity InvoiceDate  \
# 0  C503527     10002  INFLATABLE POLITICAL GLOBE        200      4/1/10
# 1  C507219     10002  INFLATABLE POLITICAL GLOBE          1      5/6/10
# 2  C508132     10002  INFLATABLE POLITICAL GLOBE        400     5/13/10
# 3  C508134     10002  INFLATABLE POLITICAL GLOBE        400     5/13/10
# 4  C508140     10002  INFLATABLE POLITICAL GLOBE        200     5/13/10
#
#    InvoiceTime  Price  Customer ID         Country SubTotal
# 0   1:13:00 PM   0.72        16019  United Kingdom   144.00
# 1   7:14:00 PM   0.85        14713  United Kingdom     0.85
# 2  10:54:00 AM   0.72        12931  United Kingdom   288.00
# 3  10:56:00 AM   0.72        12931  United Kingdom   288.00
# 4  10:58:00 AM   0.72        12931  United Kingdom   144.00

# %%
df_retail.shape
# Out:
# (713850, 10)

# %%
413084+300766
# Out:
# 713850

# %% [markdown]
# Concatenation successful

# %%
df_retail.dtypes
# Out:
# Invoice         object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# InvoiceTime     object
# Price          float64
# Customer ID      int64
# Country         object
# SubTotal        object
# dtype: object

# %%
df_retail['InvoiceDateTime'] = df_retail['InvoiceDate'] + " " + df_retail['InvoiceTime']

# %%
df_retail.head()
# Out:
#    Invoice StockCode                  Description  Quantity InvoiceDate  \
# 0  C503527     10002  INFLATABLE POLITICAL GLOBE        200      4/1/10
# 1  C507219     10002  INFLATABLE POLITICAL GLOBE          1      5/6/10
# 2  C508132     10002  INFLATABLE POLITICAL GLOBE        400     5/13/10
# 3  C508134     10002  INFLATABLE POLITICAL GLOBE        400     5/13/10
# 4  C508140     10002  INFLATABLE POLITICAL GLOBE        200     5/13/10
#
#    InvoiceTime  Price  Customer ID         Country SubTotal  \
# 0   1:13:00 PM   0.72        16019  United Kingdom   144.00
# 1   7:14:00 PM   0.85        14713  United Kingdom     0.85
# 2  10:54:00 AM   0.72        12931  United Kingdom   288.00
# 3  10:56:00 AM   0.72        12931  United Kingdom   288.00
# 4  10:58:00 AM   0.72        12931  United Kingdom   144.00
#
#        InvoiceDateTime
# 0    4/1/10 1:13:00 PM
# 1    5/6/10 7:14:00 PM
# 2  5/13/10 10:54:00 AM
# 3  5/13/10 10:56:00 AM
# 4  5/13/10 10:58:00 AM

# %%
#df_retail['InvoiceDateTime'] = pd.to_datetime(df_retail['InvoiceDateTime'])

# %%
df_retail.head()
# Out:
#    Invoice StockCode                  Description  Quantity InvoiceDate  \
# 0  C503527     10002  INFLATABLE POLITICAL GLOBE        200      4/1/10
# 1  C507219     10002  INFLATABLE POLITICAL GLOBE          1      5/6/10
# 2  C508132     10002  INFLATABLE POLITICAL GLOBE        400     5/13/10
# 3  C508134     10002  INFLATABLE POLITICAL GLOBE        400     5/13/10
# 4  C508140     10002  INFLATABLE POLITICAL GLOBE        200     5/13/10
#
#    InvoiceTime  Price  Customer ID         Country SubTotal  \
# 0   1:13:00 PM   0.72        16019  United Kingdom   144.00
# 1   7:14:00 PM   0.85        14713  United Kingdom     0.85
# 2  10:54:00 AM   0.72        12931  United Kingdom   288.00
# 3  10:56:00 AM   0.72        12931  United Kingdom   288.00
# 4  10:58:00 AM   0.72        12931  United Kingdom   144.00
#
#        InvoiceDateTime
# 0    4/1/10 1:13:00 PM
# 1    5/6/10 7:14:00 PM
# 2  5/13/10 10:54:00 AM
# 3  5/13/10 10:56:00 AM
# 4  5/13/10 10:58:00 AM

# %%
df_retail.dtypes
# Out:
# Invoice             object
# StockCode           object
# Description         object
# Quantity             int64
# InvoiceDate         object
# InvoiceTime         object
# Price              float64
# Customer ID          int64
# Country             object
# SubTotal            object
# InvoiceDateTime     object
# dtype: object

# %%
del df_retail['InvoiceDate']

# %%
del df_retail['InvoiceTime']

# %%
df_retail.head()
# Out:
#    Invoice StockCode                  Description  Quantity  Price  \
# 0  C503527     10002  INFLATABLE POLITICAL GLOBE        200   0.72
# 1  C507219     10002  INFLATABLE POLITICAL GLOBE          1   0.85
# 2  C508132     10002  INFLATABLE POLITICAL GLOBE        400   0.72
# 3  C508134     10002  INFLATABLE POLITICAL GLOBE        400   0.72
# 4  C508140     10002  INFLATABLE POLITICAL GLOBE        200   0.72
#
#    Customer ID         Country SubTotal      InvoiceDateTime
# 0        16019  United Kingdom   144.00    4/1/10 1:13:00 PM
# 1        14713  United Kingdom     0.85    5/6/10 7:14:00 PM
# 2        12931  United Kingdom   288.00  5/13/10 10:54:00 AM
# 3        12931  United Kingdom   288.00  5/13/10 10:56:00 AM
# 4        12931  United Kingdom   144.00  5/13/10 10:58:00 AM

# %%
df_retail = df_retail.rename(columns={"Customer ID": "CustomerID"})

# %%
df_retail.head()
# Out:
#    Invoice StockCode                  Description  Quantity  Price  \
# 0  C503527     10002  INFLATABLE POLITICAL GLOBE        200   0.72
# 1  C507219     10002  INFLATABLE POLITICAL GLOBE          1   0.85
# 2  C508132     10002  INFLATABLE POLITICAL GLOBE        400   0.72
# 3  C508134     10002  INFLATABLE POLITICAL GLOBE        400   0.72
# 4  C508140     10002  INFLATABLE POLITICAL GLOBE        200   0.72
#
#    CustomerID         Country SubTotal      InvoiceDateTime
# 0       16019  United Kingdom   144.00    4/1/10 1:13:00 PM
# 1       14713  United Kingdom     0.85    5/6/10 7:14:00 PM
# 2       12931  United Kingdom   288.00  5/13/10 10:54:00 AM
# 3       12931  United Kingdom   288.00  5/13/10 10:56:00 AM
# 4       12931  United Kingdom   144.00  5/13/10 10:58:00 AM

# %%
df_retail.shape
# Out:
# (713850, 9)

# %%
df_retail['Year'] = pd.DatetimeIndex(df_retail['InvoiceDateTime']).year

# %%
df_retail['Month'] = pd.DatetimeIndex(df_retail['InvoiceDateTime']).month

# %%
df_retail['Day'] = pd.DatetimeIndex(df_retail['InvoiceDateTime']).day

# %%
df_retail['Hour'] = pd.DatetimeIndex(df_retail['InvoiceDateTime']).hour

# %%
df_retail['Minute'] = pd.DatetimeIndex(df_retail['InvoiceDateTime']).minute

# %%
df_retail.head()
# Out:
#    Invoice StockCode                  Description  Quantity  Price  \
# 0  C503527     10002  INFLATABLE POLITICAL GLOBE        200   0.72
# 1  C507219     10002  INFLATABLE POLITICAL GLOBE          1   0.85
# 2  C508132     10002  INFLATABLE POLITICAL GLOBE        400   0.72
# 3  C508134     10002  INFLATABLE POLITICAL GLOBE        400   0.72
# 4  C508140     10002  INFLATABLE POLITICAL GLOBE        200   0.72
#
#    CustomerID         Country SubTotal      InvoiceDateTime  Year  Month  Day  \
# 0       16019  United Kingdom   144.00    4/1/10 1:13:00 PM  2010      4    1
# 1       14713  United Kingdom     0.85    5/6/10 7:14:00 PM  2010      5    6
# 2       12931  United Kingdom   288.00  5/13/10 10:54:00 AM  2010      5   13
# 3       12931  United Kingdom   288.00  5/13/10 10:56:00 AM  2010      5   13
# 4       12931  United Kingdom   144.00  5/13/10 10:58:00 AM  2010      5   13
#
#    Hour  Minute
# 0    13      13
# 1    19      14
# 2    10      54
# 3    10      56
# ...

# %%
df_retail.dtypes
# Out:
# Invoice             object
# StockCode           object
# Description         object
# Quantity             int64
# Price              float64
# CustomerID           int64
# Country             object
# SubTotal            object
# InvoiceDateTime     object
# Year                 int64
# Month                int64
# Day                  int64
# Hour                 int64
# Minute               int64
# dtype: object

# %%
df_retail.head()
# Out:
#    Invoice StockCode                  Description  Quantity  Price  \
# 0  C503527     10002  INFLATABLE POLITICAL GLOBE        200   0.72
# 1  C507219     10002  INFLATABLE POLITICAL GLOBE          1   0.85
# 2  C508132     10002  INFLATABLE POLITICAL GLOBE        400   0.72
# 3  C508134     10002  INFLATABLE POLITICAL GLOBE        400   0.72
# 4  C508140     10002  INFLATABLE POLITICAL GLOBE        200   0.72
#
#    CustomerID         Country SubTotal      InvoiceDateTime  Year  Month  Day  \
# 0       16019  United Kingdom   144.00    4/1/10 1:13:00 PM  2010      4    1
# 1       14713  United Kingdom     0.85    5/6/10 7:14:00 PM  2010      5    6
# 2       12931  United Kingdom   288.00  5/13/10 10:54:00 AM  2010      5   13
# 3       12931  United Kingdom   288.00  5/13/10 10:56:00 AM  2010      5   13
# 4       12931  United Kingdom   144.00  5/13/10 10:58:00 AM  2010      5   13
#
#    Hour  Minute
# 0    13      13
# 1    19      14
# 2    10      54
# 3    10      56
# ...

# %%
df_retail.to_csv('Online_Retail_Data.csv')
